# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_file = 'data/Assignment_1_Data.csv'
df = pd.read_csv(csv_file)
plt.scatter(df['x'], df['y'])

# %%
# link_msci_world = 'https://curvo.eu/6fbc14e5-bd88-4fa1-86bc-9d4e2da8c821'
# df = pd.read_csv(link_msci_world)
# df.head()

# %%
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# Define the time period
start = datetime(2023, 1, 30)
end = datetime(2025, 1, 30)

# Create a Point for Oslo, Norway (latitude, longitude, elevation)
oslo = Point(59.9139, 10.7522, 23)

# Retrieve daily data for Oslo
data = Daily(oslo, start, end)
data = data.fetch()

# Display the retrieved data
print(data)

# Plot the average, minimum, and maximum temperatures
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.title('Daily Temperatures in Oslo (2023-2025)')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.show()
# Out:
#             tavg  tmin  tmax  prcp   snow   wdir  wspd  wpgt    pres  tsun
# time
# 2023-01-30   4.0   0.2   7.6   0.0  120.0  278.0  13.4  42.0   988.9   NaN
# 2023-01-31  -0.6  -2.6   3.0   0.4  120.0  350.0   4.2  31.0   996.8   NaN
# 2023-02-01  -1.7  -3.0  -0.3   0.0  130.0   18.0   8.2  28.0   994.6   NaN
# 2023-02-02  -4.7  -7.5   1.0   0.6  130.0   24.0   4.1  13.0  1013.5   NaN
# 2023-02-03  -2.5  -5.2  -1.4   0.3  140.0   27.0  13.9  40.0  1015.3   NaN
# ...          ...   ...   ...   ...    ...    ...   ...   ...     ...   ...
# 2025-01-26   2.2  -0.1   4.5   0.1    NaN  199.0   7.1  38.0  1000.0   NaN
# 2025-01-27   1.5   0.4   2.7   3.1    NaN   80.0  11.6  36.0   994.3   NaN
# 2025-01-28   2.3   1.0   3.3  10.0    NaN   30.0   9.0  24.0   994.3   NaN
# 2025-01-29   3.4   2.6   4.3   0.3    NaN   13.0  10.1  31.0   999.6   NaN
# 2025-01-30   0.1  -2.8   2.5   0.0    NaN   33.0   4.0  11.0  1006.1   NaN
#
# [732 rows x 10 columns]
